# %%
from transformers import AutoModelForCausalLM, BitsAndBytesConfig
import torch.nn as nn

model_name = 'gpt2'

# 将模型配置为以 8-bit 量化的方式加载
bnb_config = BitsAndBytesConfig(load_in_8bit=True)

# 加载模型，并根据设备自动分配
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map='auto'
)

# 打印模型的架构
print(model)

# 打印模型的参数名称和数据类型
print(f"\n打印模型 {model_name} 的参数信息:\n")
for name, param in model.named_parameters():
    print(f"参数名称: {name}, 数据类型: {param.dtype}")
# Out:
# 2025-08-19 13:49:05.599900: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-19 13:49:05.810926: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755582545.887709   32233 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755582545.910360   32233 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755582546.079804   32233 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755582546.079830   32233 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755582546.079831   32233 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755582546.079833   32233 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-19 13:49:06.100369: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Linear8bitLt(in_features=768, out_features=2304, bias=True)
#           (c_proj): Linear8bitLt(in_features=768, out_features=768, bias=True)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Linear8bitLt(in_features=768, out_features=3072, bias=True)
#           (c_proj): Linear8bitLt(in_features=3072, out_features=768, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )
#
# 打印模型 gpt2 的参数信息:
#
# 参数名称: transformer.wte.weight, 数据类型: torch.float16
# 参数名称: transformer.wpe.weight, 数据类型: torch.float16
# 参数名称: transformer.h.0.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.0.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.0.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.0.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.0.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.0.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.0.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.0.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.0.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.0.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.0.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.0.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.1.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.1.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.1.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.1.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.1.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.1.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.1.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.1.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.1.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.1.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.1.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.1.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.2.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.2.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.2.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.2.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.2.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.2.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.2.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.2.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.2.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.2.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.2.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.2.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.3.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.3.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.3.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.3.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.3.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.3.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.3.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.3.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.3.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.3.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.3.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.3.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.4.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.4.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.4.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.4.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.4.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.4.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.4.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.4.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.4.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.4.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.4.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.4.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.5.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.5.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.5.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.5.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.5.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.5.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.5.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.5.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.5.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.5.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.5.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.5.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.6.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.6.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.6.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.6.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.6.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.6.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.6.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.6.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.6.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.6.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.6.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.6.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.7.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.7.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.7.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.7.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.7.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.7.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.7.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.7.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.7.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.7.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.7.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.7.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.8.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.8.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.8.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.8.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.8.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.8.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.8.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.8.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.8.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.8.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.8.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.8.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.9.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.9.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.9.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.9.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.9.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.9.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.9.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.9.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.9.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.9.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.9.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.9.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.10.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.10.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.10.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.10.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.10.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.10.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.10.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.10.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.10.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.10.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.10.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.10.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.11.ln_1.weight, 数据类型: torch.float16
# 参数名称: transformer.h.11.ln_1.bias, 数据类型: torch.float16
# 参数名称: transformer.h.11.attn.c_attn.weight, 数据类型: torch.int8
# 参数名称: transformer.h.11.attn.c_attn.bias, 数据类型: torch.float16
# 参数名称: transformer.h.11.attn.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.11.attn.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.h.11.ln_2.weight, 数据类型: torch.float16
# 参数名称: transformer.h.11.ln_2.bias, 数据类型: torch.float16
# 参数名称: transformer.h.11.mlp.c_fc.weight, 数据类型: torch.int8
# 参数名称: transformer.h.11.mlp.c_fc.bias, 数据类型: torch.float16
# 参数名称: transformer.h.11.mlp.c_proj.weight, 数据类型: torch.int8
# 参数名称: transformer.h.11.mlp.c_proj.bias, 数据类型: torch.float16
# 参数名称: transformer.ln_f.weight, 数据类型: torch.float16
# 参数名称: transformer.ln_f.bias, 数据类型: torch.float16
